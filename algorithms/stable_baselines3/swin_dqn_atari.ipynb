# %%
from datetime import datetime

import torch

from gymnasium import spaces

from stable_baselines3 import DQN
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.preprocessing import is_image_space
from stable_baselines3.dqn.policies import BaseFeaturesExtractor
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack

from transformers import SwinModel, SwinConfig

# %%
SWIN_CONFIG = SwinConfig(
    image_size=84,
    patch_size=3,
    num_channels=4,
    embed_dim=96,
    depths=[2, 3, 2],
    num_heads=[3, 3, 6],
    window_size=7,
    mlp_ratio=4.0,
    drop_path_rate=0.1,
)

# %%
class SwinDQN(BaseFeaturesExtractor):
    def __init__(self, observation_space: spaces.Box, features_dim: int = 384, normalized_image: bool = False,):
        assert isinstance(observation_space, spaces.Box), (
            "SwinDQN must be used with a gym.spaces.Box ",
            f"observation space, not {observation_space}",
        )
        super().__init__(observation_space, features_dim)
        # We assume CxHxW images (channels first)
        # Re-ordering will be done by pre-preprocessing or wrapper
        assert is_image_space(observation_space, check_channels=False, normalized_image=normalized_image), (
            "You should use SwinDQN "
            f"only with images not with {observation_space}\n"
            "(you are probably using `CnnPolicy` instead of `MlpPolicy` or `MultiInputPolicy`)\n"
            "If you are using `VecNormalize` or already normalized channel-first images "
            "you should pass `normalize_images=False`: \n"
            "https://stable-baselines3.readthedocs.io/en/master/guide/custom_env.html"
        )

        num_input_channels = observation_space.shape[0]
        config = SwinConfig(
            image_size=84,
            patch_size=3,
            num_channels=num_input_channels,
            embed_dim=96,
            depths=[2, 3, 2],
            num_heads=[3, 3, 6],
            window_size=7,
            mlp_ratio=4.0,
            drop_path_rate=0.1,
        )

        self.swin = SwinModel(config)

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.swin(observations).pooler_output

# %%
env = make_atari_env("ALE/Pong-v5", n_envs=1, seed=42, env_kwargs={"full_action_space": False, "frameskip": 1})
# Frame-stacking with 4 frames
env = VecFrameStack(env, n_stack=4)

NAME = "Swin_DQN_Pong-v5"

current_datetime_str = datetime.now().strftime("%d-%m-%Y_%H:%M:%S")

checkpoint_callback = CheckpointCallback(
    save_freq=500_000,
    save_path=f"runs/checkpoints/{NAME}_{current_datetime_str}",
    name_prefix=NAME,
    save_replay_buffer=True,
    verbose=2
    
)

policy_kwargs = dict(
    features_extractor_class=SwinDQN,
    net_arch=[],
)

model = DQN("CnnPolicy",
            env,
            policy_kwargs=policy_kwargs,
            verbose=1,
            tensorboard_log="runs/logs/",
            batch_size=32,
            buffer_size=10_000,
            exploration_final_eps=0.01,
            exploration_fraction=0.1,
            gradient_steps=1,
            learning_rate=0.0001,
            learning_starts=100_000,
            optimize_memory_usage=True,
            replay_buffer_kwargs={"handle_timeout_termination": False},
            target_update_interval=1000,
            train_freq=4,)
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(10_000_000, tb_log_name=f"{NAME}_{current_datetime_str}", callback=checkpoint_callback)

# Save at the end of training
model.save(f"runs/final_saves/{NAME}_{current_datetime_str}/{NAME}")
model.save_replay_buffer(f"runs/final_saves/{NAME}_{current_datetime_str}/{NAME}")
# Out:
# Logging to runs/logs/Swin_DQN_Pong-v5_11-04-2023_16:03:09_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1965     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3601     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1974     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 7199     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1980     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 10826    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.58e+03 |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1985     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 14241    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65e+03 |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1990     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 18128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1986     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 21570    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1993     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 25136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1998     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 28794    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1997     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 32307    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2001     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 36021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2001     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 39734    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2000     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 43118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2002     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 46953    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65e+03 |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2004     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 50784    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2004     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 53946    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2005     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 57703    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.64e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2006     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 61448    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2007     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 65013    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.64e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2007     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 68785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.64e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2008     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 72464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 2008     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 76257    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 2009     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 80330    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 2010     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 83825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 2010     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 87849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 2010     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 91466    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 2011     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 94998    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 2009     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 98492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 998      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 102090   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0171   |
# |    n_updates        | 522      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 578      |
# |    time_elapsed     | 182      |
# |    total_timesteps  | 105638   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0173   |
# |    n_updates        | 1409     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 415      |
# |    time_elapsed     | 262      |
# |    total_timesteps  | 109198   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00473  |
# |    n_updates        | 2299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 331      |
# |    time_elapsed     | 339      |
# |    total_timesteps  | 112564   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 3140     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 275      |
# |    time_elapsed     | 422      |
# |    total_timesteps  | 116175   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0291   |
# |    n_updates        | 4043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 236      |
# |    time_elapsed     | 505      |
# |    total_timesteps  | 119769   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0341   |
# |    n_updates        | 4942     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 208      |
# |    time_elapsed     | 591      |
# |    total_timesteps  | 123524   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000768 |
# |    n_updates        | 5880     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 188      |
# |    time_elapsed     | 671      |
# |    total_timesteps  | 126988   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0179   |
# |    n_updates        | 6746     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.64e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 174      |
# |    time_elapsed     | 745      |
# |    total_timesteps  | 130165   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0837   |
# |    n_updates        | 7541     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 161      |
# |    time_elapsed     | 827      |
# |    total_timesteps  | 133726   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0149   |
# |    n_updates        | 8431     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 150      |
# |    time_elapsed     | 909      |
# |    total_timesteps  | 137241   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0471   |
# |    n_updates        | 9310     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 141      |
# |    time_elapsed     | 993      |
# |    total_timesteps  | 140843   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0314   |
# |    n_updates        | 10210    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 134      |
# |    time_elapsed     | 1073     |
# |    total_timesteps  | 144267   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0402   |
# |    n_updates        | 11066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.64e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 130      |
# |    time_elapsed     | 1139     |
# |    total_timesteps  | 148257   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00584  |
# |    n_updates        | 12064    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 128      |
# |    time_elapsed     | 1179     |
# |    total_timesteps  | 152064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 13015    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 127      |
# |    time_elapsed     | 1218     |
# |    total_timesteps  | 155709   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 13927    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.64e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 126      |
# |    time_elapsed     | 1256     |
# |    total_timesteps  | 159296   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.007    |
# |    n_updates        | 14823    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.64e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 125      |
# |    time_elapsed     | 1296     |
# |    total_timesteps  | 163009   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00089  |
# |    n_updates        | 15752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.64e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 124      |
# |    time_elapsed     | 1335     |
# |    total_timesteps  | 166619   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00142  |
# |    n_updates        | 16654    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 123      |
# |    time_elapsed     | 1375     |
# |    total_timesteps  | 170380   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0046   |
# |    n_updates        | 17594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 123      |
# |    time_elapsed     | 1413     |
# |    total_timesteps  | 173842   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00238  |
# |    n_updates        | 18460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 122      |
# |    time_elapsed     | 1450     |
# |    total_timesteps  | 177332   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00294  |
# |    n_updates        | 19332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.821    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 121      |
# |    time_elapsed     | 1488     |
# |    total_timesteps  | 180866   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00108  |
# |    n_updates        | 20216    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 120      |
# |    time_elapsed     | 1530     |
# |    total_timesteps  | 184671   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00244  |
# |    n_updates        | 21167    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 119      |
# |    time_elapsed     | 1578     |
# |    total_timesteps  | 188254   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00217  |
# |    n_updates        | 22063    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 115      |
# |    time_elapsed     | 1662     |
# |    total_timesteps  | 191751   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00134  |
# |    n_updates        | 22937    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 111      |
# |    time_elapsed     | 1751     |
# |    total_timesteps  | 195463   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0053   |
# |    n_updates        | 23865    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 108      |
# |    time_elapsed     | 1831     |
# |    total_timesteps  | 198838   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00228  |
# |    n_updates        | 24709    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 105      |
# |    time_elapsed     | 1921     |
# |    total_timesteps  | 202615   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0027   |
# |    n_updates        | 25653    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 102      |
# |    time_elapsed     | 2007     |
# |    total_timesteps  | 206179   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00116  |
# |    n_updates        | 26544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.792    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 100      |
# |    time_elapsed     | 2094     |
# |    total_timesteps  | 209768   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 27441    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 97       |
# |    time_elapsed     | 2181     |
# |    total_timesteps  | 213418   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.028    |
# |    n_updates        | 28354    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 95       |
# |    time_elapsed     | 2266     |
# |    total_timesteps  | 216957   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00201  |
# |    n_updates        | 29239    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.781    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 93       |
# |    time_elapsed     | 2362     |
# |    total_timesteps  | 220950   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00173  |
# |    n_updates        | 30237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 91       |
# |    time_elapsed     | 2458     |
# |    total_timesteps  | 224878   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00473  |
# |    n_updates        | 31219    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 89       |
# |    time_elapsed     | 2551     |
# |    total_timesteps  | 228736   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00437  |
# |    n_updates        | 32183    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 88       |
# |    time_elapsed     | 2634     |
# |    total_timesteps  | 232188   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00173  |
# |    n_updates        | 33046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 86       |
# |    time_elapsed     | 2722     |
# |    total_timesteps  | 235775   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00154  |
# |    n_updates        | 33943    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 85       |
# |    time_elapsed     | 2812     |
# |    total_timesteps  | 239554   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00138  |
# |    n_updates        | 34888    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.759    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 83       |
# |    time_elapsed     | 2901     |
# |    total_timesteps  | 243243   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00366  |
# |    n_updates        | 35810    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 82       |
# |    time_elapsed     | 2981     |
# |    total_timesteps  | 246574   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00193  |
# |    n_updates        | 36643    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.752    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 81       |
# |    time_elapsed     | 3066     |
# |    total_timesteps  | 250103   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00267  |
# |    n_updates        | 37525    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 80       |
# |    time_elapsed     | 3154     |
# |    total_timesteps  | 253760   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00199  |
# |    n_updates        | 38439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.745    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 79       |
# |    time_elapsed     | 3246     |
# |    total_timesteps  | 257582   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0016   |
# |    n_updates        | 39395    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.741    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 78       |
# |    time_elapsed     | 3338     |
# |    total_timesteps  | 261380   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00206  |
# |    n_updates        | 40344    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.738    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 77       |
# |    time_elapsed     | 3429     |
# |    total_timesteps  | 265134   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00111  |
# |    n_updates        | 41283    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 76       |
# |    time_elapsed     | 3522     |
# |    total_timesteps  | 269005   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00702  |
# |    n_updates        | 42251    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.73     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 75       |
# |    time_elapsed     | 3610     |
# |    total_timesteps  | 272641   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00168  |
# |    n_updates        | 43160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 74       |
# |    time_elapsed     | 3690     |
# |    total_timesteps  | 275899   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00428  |
# |    n_updates        | 43974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 73       |
# |    time_elapsed     | 3787     |
# |    total_timesteps  | 279932   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00833  |
# |    n_updates        | 44982    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.719    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 73       |
# |    time_elapsed     | 3884     |
# |    total_timesteps  | 283935   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0012   |
# |    n_updates        | 45983    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 72       |
# |    time_elapsed     | 3976     |
# |    total_timesteps  | 287731   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000739 |
# |    n_updates        | 46932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.712    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 71       |
# |    time_elapsed     | 4061     |
# |    total_timesteps  | 291244   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00278  |
# |    n_updates        | 47810    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.708    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 70       |
# |    time_elapsed     | 4162     |
# |    total_timesteps  | 295382   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00191  |
# |    n_updates        | 48845    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.704    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 70       |
# |    time_elapsed     | 4251     |
# |    total_timesteps  | 299042   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00212  |
# |    n_updates        | 49760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.7      |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 69       |
# |    time_elapsed     | 4335     |
# |    total_timesteps  | 302543   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00196  |
# |    n_updates        | 50635    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.697    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 69       |
# |    time_elapsed     | 4418     |
# |    total_timesteps  | 305917   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00113  |
# |    n_updates        | 51479    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.693    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 68       |
# |    time_elapsed     | 4515     |
# |    total_timesteps  | 309942   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 52485    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.69     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 68       |
# |    time_elapsed     | 4602     |
# |    total_timesteps  | 313478   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000858 |
# |    n_updates        | 53369    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.686    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 67       |
# |    time_elapsed     | 4692     |
# |    total_timesteps  | 317152   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00151  |
# |    n_updates        | 54287    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.683    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 67       |
# |    time_elapsed     | 4778     |
# |    total_timesteps  | 320666   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00128  |
# |    n_updates        | 55166    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.679    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 66       |
# |    time_elapsed     | 4869     |
# |    total_timesteps  | 324405   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00447  |
# |    n_updates        | 56101    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.675    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 66       |
# |    time_elapsed     | 4961     |
# |    total_timesteps  | 328163   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0066   |
# |    n_updates        | 57040    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.672    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 65       |
# |    time_elapsed     | 5048     |
# |    total_timesteps  | 331704   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00229  |
# |    n_updates        | 57925    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.668    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 65       |
# |    time_elapsed     | 5137     |
# |    total_timesteps  | 335323   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000533 |
# |    n_updates        | 58830    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.665    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 64       |
# |    time_elapsed     | 5217     |
# |    total_timesteps  | 338570   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00312  |
# |    n_updates        | 59642    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.661    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 64       |
# |    time_elapsed     | 5306     |
# |    total_timesteps  | 342177   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.002    |
# |    n_updates        | 60544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 64       |
# |    time_elapsed     | 5398     |
# |    total_timesteps  | 345943   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00123  |
# |    n_updates        | 61485    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.654    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 63       |
# |    time_elapsed     | 5491     |
# |    total_timesteps  | 349741   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00203  |
# |    n_updates        | 62435    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.65     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 63       |
# |    time_elapsed     | 5582     |
# |    total_timesteps  | 353402   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00498  |
# |    n_updates        | 63350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.646    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 62       |
# |    time_elapsed     | 5677     |
# |    total_timesteps  | 357261   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00322  |
# |    n_updates        | 64315    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.642    |
# | time/               |          |
# |    episodes         | 396      |
# ...
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.598    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 58       |
# |    time_elapsed     | 6897     |
# |    total_timesteps  | 406459   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00929  |
# |    n_updates        | 76614    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.594    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 58       |
# |    time_elapsed     | 6993     |
# |    total_timesteps  | 410286   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 77571    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 58       |
# |    time_elapsed     | 7085     |
# |    total_timesteps  | 413996   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00245  |
# |    n_updates        | 78498    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.587    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 58       |
# |    time_elapsed     | 7169     |
# |    total_timesteps  | 417330   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0043   |
# |    n_updates        | 79332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.583    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 57       |
# |    time_elapsed     | 7276     |
# |    total_timesteps  | 421619   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0275   |
# |    n_updates        | 80404    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.578    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 57       |
# |    time_elapsed     | 7383     |
# |    total_timesteps  | 425871   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00958  |
# |    n_updates        | 81467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.574    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 57       |
# |    time_elapsed     | 7487     |
# |    total_timesteps  | 430023   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0063   |
# |    n_updates        | 82505    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.571    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 57       |
# |    time_elapsed     | 7572     |
# |    total_timesteps  | 433403   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00221  |
# |    n_updates        | 83350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.567    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 57       |
# |    time_elapsed     | 7674     |
# |    total_timesteps  | 437466   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00716  |
# |    n_updates        | 84366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.563    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 56       |
# |    time_elapsed     | 7772     |
# |    total_timesteps  | 441373   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00751  |
# |    n_updates        | 85343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.56     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 56       |
# |    time_elapsed     | 7862     |
# |    total_timesteps  | 444937   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00181  |
# |    n_updates        | 86234    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.556    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 56       |
# |    time_elapsed     | 7964     |
# |    total_timesteps  | 448972   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00445  |
# |    n_updates        | 87242    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.85e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.552    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 56       |
# |    time_elapsed     | 8066     |
# |    total_timesteps  | 452984   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00879  |
# |    n_updates        | 88245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 55       |
# |    time_elapsed     | 8176     |
# |    total_timesteps  | 457335   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00137  |
# |    n_updates        | 89333    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.543    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 55       |
# |    time_elapsed     | 8274     |
# |    total_timesteps  | 461225   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00511  |
# |    n_updates        | 90306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.54     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 55       |
# |    time_elapsed     | 8369     |
# |    total_timesteps  | 464960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000941 |
# |    n_updates        | 91239    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.536    |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 55       |
# |    time_elapsed     | 8464     |
# |    total_timesteps  | 468727   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 92181    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.532    |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 55       |
# |    time_elapsed     | 8557     |
# |    total_timesteps  | 472366   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00646  |
# |    n_updates        | 93091    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.528    |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 55       |
# |    time_elapsed     | 8661     |
# |    total_timesteps  | 476503   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00225  |
# |    n_updates        | 94125    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.9e+03  |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.524    |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 54       |
# |    time_elapsed     | 8770     |
# |    total_timesteps  | 480774   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00143  |
# |    n_updates        | 95193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.52     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 54       |
# |    time_elapsed     | 8866     |
# |    total_timesteps  | 484502   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00387  |
# |    n_updates        | 96125    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.516    |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 54       |
# |    time_elapsed     | 8966     |
# |    total_timesteps  | 488468   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00721  |
# |    n_updates        | 97116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.9e+03  |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.513    |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 54       |
# |    time_elapsed     | 9058     |
# |    total_timesteps  | 492061   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0056   |
# |    n_updates        | 98015    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.509    |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 54       |
# |    time_elapsed     | 9168     |
# |    total_timesteps  | 496387   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00369  |
# |    n_updates        | 99096    |
# ----------------------------------
# Saving model checkpoint to runs/checkpoints/Swin_DQN_Pong-v5_11-04-2023_16:03:09/Swin_DQN_Pong-v5_500000_steps.zip
# Saving model replay buffer checkpoint to runs/checkpoints/Swin_DQN_Pong-v5_11-04-2023_16:03:09/Swin_DQN_Pong-v5_replay_buffer_500000_steps.pkl
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 53       |
# |    time_elapsed     | 9279     |
# |    total_timesteps  | 500727   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00325  |
# |    n_updates        | 100181   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.5      |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 53       |
# |    time_elapsed     | 9390     |
# |    total_timesteps  | 505069   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0021   |
# |    n_updates        | 101267   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.496    |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 53       |
# |    time_elapsed     | 9499     |
# |    total_timesteps  | 509352   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00277  |
# |    n_updates        | 102337   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.492    |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 53       |
# |    time_elapsed     | 9600     |
# |    total_timesteps  | 513311   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00657  |
# |    n_updates        | 103327   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | -20      |
# |    exploration_rate | 0.488    |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 53       |
# |    time_elapsed     | 9711     |
# |    total_timesteps  | 517647   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00557  |
# |    n_updates        | 104411   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | -20      |
# |    exploration_rate | 0.483    |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 53       |
# |    time_elapsed     | 9818     |
# |    total_timesteps  | 521812   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00492  |
# |    n_updates        | 105452   |
# ----------------------------------
