# %% [markdown]
# # Basic Usage: Training, Saving, Loading
# In the following example, we will train, save and load a DQN model on the Lunar Lander environment.
# Link: [https://stable-baselines3.readthedocs.io/en/master/guide/examples.html#basic-usage-training-saving-loading](https://stable-baselines3.readthedocs.io/en/master/guide/examples.html#basic-usage-training-saving-loading)

# %%
import gymnasium as gym

from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Create environment
env = gym.make("LunarLander-v2")

# Instantiate the agent
model = DQN("MlpPolicy", env, verbose=1)
# Train the agent and display a progress bar
model.learn(total_timesteps=int(2e5), progress_bar=True)
# Save the agent
model.save("dqn_lunar")

del model # Delete trained model to demonstrate loading
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Output()
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3022     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 410      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.5     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4213     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 780      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 5195     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1252     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.9     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 5489     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1598     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.6     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 5822     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1952     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.6     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 6057     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2270     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 6233     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2651     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.8     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 6437     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3064     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95       |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 6520     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3421     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 6685     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3815     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 6715     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 6732     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4477     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 6778     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.755    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 6858     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5156     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.735    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 6930     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.717    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 7013     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5965     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 7079     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6396     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.679    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 7152     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6764     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.66     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 7220     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7155     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.64     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 7248     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7573     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.623    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 7295     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.603    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 7329     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8355     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.585    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 7368     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8745     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.569    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 7371     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9072     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.509    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 7379     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10337    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.492    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 7367     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.477    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 7377     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11008    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.459    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 7376     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11393    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.442    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 7395     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11738    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.425    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 7390     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12112    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.408    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 7414     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12471    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.388    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 7418     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12886    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.37     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 7434     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.354    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 7384     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13595    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.337    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 7364     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13956    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.321    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 7352     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 14290    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.303    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 7381     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 14680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.289    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 7393     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 14972    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.273    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 7398     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15313    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.256    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 7415     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15665    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.241    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 7420     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15983    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.222    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 7432     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16381    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.6     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.205    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 7438     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16727    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.6     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.187    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 7449     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17117    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.5     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.172    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 7399     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17427    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.3     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.156    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 7364     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.5     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.14     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 7357     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.2     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.118    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 7353     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18564    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.9     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.0994   |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 7357     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.0814   |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 7373     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.0651   |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 7348     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19683    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 7339     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 20041    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 7342     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 20410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 7352     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 20712    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 7372     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 21099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 7379     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 21458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.9     |
# |    ep_rew_mean      | -158     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 7391     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 21776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89       |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 7392     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 22172    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 7402     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 22542    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.8     |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 7398     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 22841    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -157     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 7413     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 23263    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.1     |
# |    ep_rew_mean      | -153     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 7408     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 23592    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -153     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 7398     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 23925    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.1     |
# |    ep_rew_mean      | -152     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 7395     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 24222    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 7401     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 24637    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -155     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 7398     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 25032    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -154     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 7381     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 25347    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -157     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 7384     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 25840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 7386     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 26138    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 7397     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 26525    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 7399     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 26883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 7413     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 27271    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 7402     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 27570    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 7415     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 27942    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 7400     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 28363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 7408     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 28816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 7405     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 29152    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 7414     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 29440    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 7415     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 29813    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 7410     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 30190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 7406     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 30487    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 7400     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 30926    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 7373     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 31312    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 7363     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 31675    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 7351     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 32047    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 7350     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 32383    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 7325     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 32823    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 7324     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 33198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 7320     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 33551    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | -206     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 7312     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 33975    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 7324     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 34397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 7313     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 34705    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 7319     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 35072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 7323     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 35416    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 7334     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 35791    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 7346     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 36202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 7338     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 36518    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 7341     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 36872    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 7341     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 37198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 7343     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 37600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 7340     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 37950    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 7351     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 38341    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 7339     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 38780    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 7346     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 39174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 7343     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 39512    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 7346     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 39952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 7341     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 40243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 7346     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 40699    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 7343     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 41075    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 7347     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 41440    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 7340     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 41804    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 7346     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 42158    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 7344     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 42535    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 7350     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 42825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 7355     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 43137    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 7358     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 43568    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 7361     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 43933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 7362     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 44224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 7369     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 44616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 7363     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 44964    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 7352     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 45332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 7349     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 45675    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 7359     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 46096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 7361     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 46449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -186     |
# ...
# | rollout/            |          |
# |    ep_len_mean      | 359      |
# |    ep_rew_mean      | -286     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 2110     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 87783    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.738    |
# |    n_updates        | 9445     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 383      |
# |    ep_rew_mean      | -253     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 2050     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 90829    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.75     |
# |    n_updates        | 10207    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 408      |
# |    ep_rew_mean      | -239     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 1993     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 93924    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.68     |
# |    n_updates        | 10980    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | -224     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 1932     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 97564    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.748    |
# |    n_updates        | 11890    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 468      |
# |    ep_rew_mean      | -210     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 664      |
# |    fps              | 1878     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 101350   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.09     |
# |    n_updates        | 12837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -203     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 668      |
# |    fps              | 1830     |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 105350   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.832    |
# |    n_updates        | 13837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 532      |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 672      |
# |    fps              | 1783     |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 109350   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.702    |
# |    n_updates        | 14837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 563      |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 676      |
# |    fps              | 1742     |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 113350   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.702    |
# |    n_updates        | 15837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 580      |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 1709     |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 116975   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.451    |
# |    n_updates        | 16743    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 585      |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 684      |
# |    fps              | 1683     |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 119866   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.04     |
# |    n_updates        | 17466    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 608      |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 688      |
# |    fps              | 1657     |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 123606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.413    |
# |    n_updates        | 18401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 633      |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 692      |
# |    fps              | 1633     |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 127606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.822    |
# |    n_updates        | 19401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 658      |
# |    ep_rew_mean      | -156     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 1611     |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 131606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.919    |
# |    n_updates        | 20401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 692      |
# |    ep_rew_mean      | -152     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 1594     |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 135606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.659    |
# |    n_updates        | 21401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 709      |
# |    ep_rew_mean      | -152     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 1577     |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 139606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.55     |
# |    n_updates        | 22401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 717      |
# |    ep_rew_mean      | -149     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 1557     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 143606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.834    |
# |    n_updates        | 23401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 753      |
# |    ep_rew_mean      | -138     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 1535     |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 147606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.618    |
# |    n_updates        | 24401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 769      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 1517     |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 151606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.21     |
# |    n_updates        | 25401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 792      |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 1499     |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 155606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.812    |
# |    n_updates        | 26401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 817      |
# |    ep_rew_mean      | -130     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 1486     |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 159606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.514    |
# |    n_updates        | 27401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 848      |
# |    ep_rew_mean      | -127     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 1473     |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 163606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.33     |
# |    n_updates        | 28401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 872      |
# |    ep_rew_mean      | -124     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 1459     |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 167606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.61     |
# |    n_updates        | 29401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 906      |
# |    ep_rew_mean      | -121     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 1448     |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 171606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.988    |
# |    n_updates        | 30401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 928      |
# |    ep_rew_mean      | -119     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 1437     |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 175606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.512    |
# |    n_updates        | 31401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 950      |
# |    ep_rew_mean      | -115     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 1428     |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 179606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.414    |
# |    n_updates        | 32401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 958      |
# |    ep_rew_mean      | -115     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 1420     |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 183606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.74     |
# |    n_updates        | 33401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 968      |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 1406     |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 187606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.91     |
# |    n_updates        | 34401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 977      |
# |    ep_rew_mean      | -114     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 1397     |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 191606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.718    |
# |    n_updates        | 35401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 980      |
# |    ep_rew_mean      | -109     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 1392     |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 195606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.488    |
# |    n_updates        | 36401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 983      |
# |    ep_rew_mean      | -110     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 1386     |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 199606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.51     |
# |    n_updates        | 37401    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
env_human = gym.make("LunarLander-v2", render_mode="human")
# Load the trained agent
model = DQN.load("dqn_lunar", env=env_human)

# Evaluate the agent
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)

# Enjoy trained agent
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
